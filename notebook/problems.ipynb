# %% [markdown]
# # Probability exercises

# %% [markdown]
# ## Exercise 1
#
# Two dices are thrown once and the total score is observed. Use a simulation to find the estimated probability that the total score is even or greater than 7.  A simulation is a repetition of the same experiment multiple times to observe its behavior:
#
# - Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices).
# - Keep track of the number of times that the sum was either greater than 7 or an even number.
# - Divide the number from step 2 by the number of iterations (1000).

# %%
import numpy as np
import random

#- Run the experiment 1000 times (roll 2 dice 1000 times, and sum the number of both dices):
np.random.seed(7)
two_dices = np.random.randint(1,7,1000)+np.random.randint(1,7,1000)

# - Keep track of the number of times that the sum was either greater than 7 or an even number:
repeat_count = []
for i in two_dices:
    if i > 7:
        repeat_count.append(True)
    elif i % 2 == 0:
        repeat_count.append(True)
    else:
        repeat_count.append(False)

print(f"The number of times a number greater than 7 appears or an even number:",(repeat_count.count(True)))

#- Divide the number from step 2 by the number of iterations (1000):
print(f"The division of getting a number greater than 7 to 1000 is:",(repeat_count.count(True)/1000*100),"%")
# Out:
# The number of times a number greater than 7 appears or an even number: 657
# The division of getting a number greater than 7 to 1000 is: 65.7 %

# %% [markdown]
# ## Exercise 2
#
# A box contains 10 white balls, 20 red balls and 30 green balls. If we take 5 balls from the box with replacement (we take the ball, observe what color it is and put it back into the box). We want to know the probability of:
#
# 1. Take 3 white and 2 red.
# 2. All are the same color.
#
# Run the experiment 1000 times and calculate the above probabilities.

# %%
import random

random.seed(7)
ball_box = {}

# Create the box of balls
for i in range(60):
    if i < 10:
        ball_box[i] = "White"
    elif (i > 9) and (i < 30):
        ball_box[i] = "Red"
    else:
        ball_box[i] = "Green"
            
def getBalls(amount):
    return [random.choice(ball_box) for _ in range(amount)]

def runExperiment(numberOfTimes):
    return [getBalls(5) for _ in range(numberOfTimes)]

experimentResult = runExperiment(1000)
p1 = 0
p2 = 0

for result in experimentResult:
    if (result.count('White') == 3 and result.count('Red') == 2):
        p1 += 1
    elif (len(set(result)) == 1):
        p2 += 1

print('Probability of 3 white balls and 2 red balls is:', np.round((p1/1000)*100,2), '%')
print('Probability of that the 5 balls is of same colour:', np.round((p2/1000)*100,2),'%')
# Out:
# Probability of 3 white balls and 2 red balls is: 0.7 %
# Probability of that the 5 balls is of same colour: 3.2 %
